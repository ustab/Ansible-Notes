# %% [markdown]
# <a href="https://colab.research.google.com/github/ustab/Ansible-Notes/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("https://data.cms.gov/provider-data/sites/default/files/resources/17fcbee365b92b458e5b0a78005d5511_1649361914/Inpatient_Rehabilitation_Facility-Conditions_Mar2022.csv")
df
# Out:
#       CMS Certification Number (CCN)  \
# 0                             013025
# 1                             013025
# 2                             013025
# 3                             013025
# 4                             013025
# ...                              ...
# 10750                         713028
# 10751                         713028
# 10752                         713028
# 10753                         713028
# 10754                         713028
#
#                                            Facility Name       Address Line 1  \
# 0      ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 1      ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 2      ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 3      ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 4      ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# ...

# %%
df.head()
# Out:
#   CMS Certification Number (CCN)  \
# 0                         013025
# 1                         013025
# 2                         013025
# 3                         013025
# 4                         013025
#
#                                        Facility Name       Address Line 1  \
# 0  ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 1  ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 2  ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 3  ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 4  ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
#
#   Address Line 2        City State  Zip Code County Name    Phone Number  \
# 0            NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 1            NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 2            NaN  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# ...

# %%
df.describe()
# Out:
#            Zip Code    CMS Region     Footnote
# count  10755.000000  10755.000000  4484.000000
# mean   53596.402510      5.372385     1.342328
# std    26842.053422      2.163951     0.474542
# min      674.000000      1.000000     1.000000
# 25%    31792.000000      4.000000     1.000000
# 50%    53405.000000      5.000000     1.000000
# 75%    76712.000000      6.000000     2.000000
# max    99508.000000     10.000000     2.000000

# %%
df.shape
# Out:
# (10755, 13)

# %%
pd.read_html("https://www.cdc.gov/ncbddd/index.html")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-84da3cc81db2> in <module>()
# ----> 1 pd.read_html("https://www.cdc.gov/ncbddd/index.html")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111         na_values=na_values,
#    1112         keep_default_na=keep_default_na,
# -> 1113         displayed_only=displayed_only,
#    1114     )
#
# ...
